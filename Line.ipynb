# %%
import matplotlib.pyplot as plt

# %%
y = [1, 4, 9, 16, 25, 36, 49, 64, 88, 18]
y2 = [1, 10, 1, 5, 5, 2, 1, 4, 8, 1]
 
x1 = [1, 16, 30, 42, 55, 68, 77, 88, 96, 100]
x2 = [1, 6, 12, 18, 28, 40, 52, 65, 78, 88]
x3 = [1, 10, 15, 55, 59, 62, 71, 74, 81, 101]

plt.plot(x1, y, 'ys-')
plt.plot(x2, y, 'go--')
plt.plot(x3, y2, 'bd-')
plt.legend(labels = ('tv', 'smartphone', 'MellamoTrung'), loc = 'upper left')
plt.grid(color = 'b', ls = '-', lw = 0.05)
plt.title('Ad effects on sales')
plt.xlabel('medium')
plt.ylabel('sales')
plt.show()
