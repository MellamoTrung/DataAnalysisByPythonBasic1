# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x,y, color = 'green', height=0.9)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#data
menMeans = [20, 35, 30, 35, 27]
womenMeans = [25, 12, 34, 20, 25]
group = np.arange(5)

#plot
plt.bar(group, menMeans, width = 0.35, color = 'r')
plt.bar(group, womenMeans, width = 0.35, bottom = menMeans, color = 'b')

#labels
plt.xlabel('Scores')
plt.ylabel('Group')
plt.xticks(group, ('G1', 'G2', 'G3', 'G4', 'G5'))
plt.yticks(np.arange(0, 81, 10))
plt.legend(labels = ['Men', 'Women'])

plt.show()
